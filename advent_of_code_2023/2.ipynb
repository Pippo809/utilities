# %% [markdown]
# # Day 2: Cube Conundrum
#
# You're launched high into the atmosphere! The apex of your trajectory just barely reaches the surface of a large island floating in the sky. You gently land in a fluffy pile of leaves. It's quite cold, but you don't see much snow. An Elf runs over to greet you.
#
# The Elf explains that you've arrived at Snow Island and apologizes for the lack of snow. He'll be happy to explain the situation, but it's a bit of a walk, so you have some time. They don't get many visitors up here; would you like to play a game in the meantime?
#
# As you walk, the Elf shows you a small bag and some cubes which are either red, green, or blue. Each time you play this game, he will hide a secret number of cubes of each color in the bag, and your goal is to figure out information about the number of cubes.
#
# To get information, once a bag has been loaded with cubes, the Elf will reach into the bag, grab a handful of random cubes, show them to you, and then put them back in the bag. He'll do this a few times per game.
#
# You play several games and record the information from each game (your puzzle input). Each game is listed with its ID number (like the 11 in Game 11: ...) followed by a semicolon-separated list of subsets of cubes that were revealed from the bag (like 3 red, 5 green, 4 blue).
#
# For example, the record of a few games might look like this:
#
# ```
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
# Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
# ```
#
#
# In game 1, three sets of cubes are revealed from the bag (and then put back again). The first set is 3 blue cubes and 4 red cubes; the second set is 1 red cube, 2 green cubes, and 6 blue cubes; the third set is only 2 green cubes.
#
# The Elf would first like to know which games would have been possible if the bag contained only 12 red cubes, 13 green cubes, and 14 blue cubes?
#
# In the example above, games 1, 2, and 5 would have been possible if the bag had been loaded with that configuration. However, game 3 would have been impossible because at one point the Elf showed you 20 red cubes at once; similarly, game 4 would also have been impossible because the Elf showed you 15 blue cubes at once. If you add up the IDs of the games that would have been possible, you get 8.
#
# Determine which games would have been possible if the bag had been loaded with only **12 red cubes, 13 green cubes, and 14 blue cubes**. What is the sum of the IDs of those games?

# %%
games = []
with open(r"advent_of_code_2023\2.txt", "+r") as file:
    games = file.readlines()

# %%
categories = ["red", "green", "blue"]

# %%
from collections import defaultdict

# 12 red cubes, 13 green cubes, and 14 blue cubes
maxims = {"red": 12, "green": 13, "blue": 14}
tot = 0
for id, game in enumerate(games):
    game = game.rstrip(r"\n")
    game = game.rstrip("\n")
    print(game)
    minigames = game.split(":")[1].split(";")
    id += 1
    valid = True
    for minigame in minigames:
        print(minigame)
        draws = minigame.split(",")
        draws_dict = defaultdict(int)
        for draw in draws:
            val, cat = draw.split(" ")[1], draw.split(" ")[2]
            print(val, cat)
            draws_dict[cat] = val
            print(draws_dict)
            print(game)
            if maxims[cat] < int(val):
                valid = False
    if valid:
        tot += id
# Out:
# Game 1: 7 blue, 4 red, 11 green; 2 red, 2 blue, 7 green; 2 red, 13 blue, 8 green; 18 blue, 7 green, 5 red
#  7 blue, 4 red, 11 green
# 7 blue
# defaultdict(<class 'int'>, {'blue': '7'})
# Game 1: 7 blue, 4 red, 11 green; 2 red, 2 blue, 7 green; 2 red, 13 blue, 8 green; 18 blue, 7 green, 5 red
# 4 red
# defaultdict(<class 'int'>, {'blue': '7', 'red': '4'})
# Game 1: 7 blue, 4 red, 11 green; 2 red, 2 blue, 7 green; 2 red, 13 blue, 8 green; 18 blue, 7 green, 5 red
# 11 green
# defaultdict(<class 'int'>, {'blue': '7', 'red': '4', 'green': '11'})
# Game 1: 7 blue, 4 red, 11 green; 2 red, 2 blue, 7 green; 2 red, 13 blue, 8 green; 18 blue, 7 green, 5 red
#  2 red, 2 blue, 7 green
# 2 red
# defaultdict(<class 'int'>, {'red': '2'})
# Game 1: 7 blue, 4 red, 11 green; 2 red, 2 blue, 7 green; 2 red, 13 blue, 8 green; 18 blue, 7 green, 5 red
# 2 blue
# defaultdict(<class 'int'>, {'red': '2', 'blue': '2'})
# Game 1: 7 blue, 4 red, 11 green; 2 red, 2 blue, 7 green; 2 red, 13 blue, 8 green; 18 blue, 7 green, 5 red
# 7 green
# defaultdict(<class 'int'>, {'red': '2', 'blue': '2', 'green': '7'})
# Game 1: 7 blue, 4 red, 11 green; 2 red, 2 blue, 7 green; 2 red, 13 blue, 8 green; 18 blue, 7 green, 5 red
#  2 red, 13 blue, 8 green
# 2 red
# defaultdict(<class 'int'>, {'red': '2'})
# Game 1: 7 blue, 4 red, 11 green; 2 red, 2 blue, 7 green; 2 red, 13 blue, 8 green; 18 blue, 7 green, 5 red
# 13 blue
# defaultdict(<class 'int'>, {'red': '2', 'blue': '13'})
# Game 1: 7 blue, 4 red, 11 green; 2 red, 2 blue, 7 green; 2 red, 13 blue, 8 green; 18 blue, 7 green, 5 red
# 8 green
# defaultdict(<class 'int'>, {'red': '2', 'blue': '13', 'green': '8'})
# Game 1: 7 blue, 4 red, 11 green; 2 red, 2 blue, 7 green; 2 red, 13 blue, 8 green; 18 blue, 7 green, 5 red
#  18 blue, 7 green, 5 red
# 18 blue
# defaultdict(<class 'int'>, {'blue': '18'})
# Game 1: 7 blue, 4 red, 11 green; 2 red, 2 blue, 7 green; 2 red, 13 blue, 8 green; 18 blue, 7 green, 5 red
# 7 green
# defaultdict(<class 'int'>, {'blue': '18', 'green': '7'})
# Game 1: 7 blue, 4 red, 11 green; 2 red, 2 blue, 7 green; 2 red, 13 blue, 8 green; 18 blue, 7 green, 5 red
# 5 red
# defaultdict(<class 'int'>, {'blue': '18', 'green': '7', 'red': '5'})
# Game 1: 7 blue, 4 red, 11 green; 2 red, 2 blue, 7 green; 2 red, 13 blue, 8 green; 18 blue, 7 green, 5 red
# Game 2: 3 green, 4 red, 4 blue; 6 red, 4 green, 4 blue; 2 blue, 4 green, 3 red
#  3 green, 4 red, 4 blue
# 3 green
# defaultdict(<class 'int'>, {'green': '3'})
# Game 2: 3 green, 4 red, 4 blue; 6 red, 4 green, 4 blue; 2 blue, 4 green, 3 red
# 4 red
# defaultdict(<class 'int'>, {'green': '3', 'red': '4'})
# Game 2: 3 green, 4 red, 4 blue; 6 red, 4 green, 4 blue; 2 blue, 4 green, 3 red
# 4 blue
# defaultdict(<class 'int'>, {'green': '3', 'red': '4', 'blue': '4'})
# Game 2: 3 green, 4 red, 4 blue; 6 red, 4 green, 4 blue; 2 blue, 4 green, 3 red
#  6 red, 4 green, 4 blue
# 6 red
# defaultdict(<class 'int'>, {'red': '6'})
# Game 2: 3 green, 4 red, 4 blue; 6 red, 4 green, 4 blue; 2 blue, 4 green, 3 red
# 4 green
# defaultdict(<class 'int'>, {'red': '6', 'green': '4'})
# Game 2: 3 green, 4 red, 4 blue; 6 red, 4 green, 4 blue; 2 blue, 4 green, 3 red
# 4 blue
# defaultdict(<class 'int'>, {'red': '6', 'green': '4', 'blue': '4'})
# Game 2: 3 green, 4 red, 4 blue; 6 red, 4 green, 4 blue; 2 blue, 4 green, 3 red
#  2 blue, 4 green, 3 red
# 2 blue
# defaultdict(<class 'int'>, {'blue': '2'})
# Game 2: 3 green, 4 red, 4 blue; 6 red, 4 green, 4 blue; 2 blue, 4 green, 3 red
# 4 green
# defaultdict(<class 'int'>, {'blue': '2', 'green': '4'})
# Game 2: 3 green, 4 red, 4 blue; 6 red, 4 green, 4 blue; 2 blue, 4 green, 3 red
# 3 red
# defaultdict(<class 'int'>, {'blue': '2', 'green': '4', 'red': '3'})
# Game 2: 3 green, 4 red, 4 blue; 6 red, 4 green, 4 blue; 2 blue, 4 green, 3 red
# Game 3: 1 red, 2 green, 3 blue; 1 red, 2 green; 2 green, 3 red; 1 blue, 2 red
#  1 red, 2 green, 3 blue
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 3: 1 red, 2 green, 3 blue; 1 red, 2 green; 2 green, 3 red; 1 blue, 2 red
# 2 green
# defaultdict(<class 'int'>, {'red': '1', 'green': '2'})
# Game 3: 1 red, 2 green, 3 blue; 1 red, 2 green; 2 green, 3 red; 1 blue, 2 red
# 3 blue
# defaultdict(<class 'int'>, {'red': '1', 'green': '2', 'blue': '3'})
# Game 3: 1 red, 2 green, 3 blue; 1 red, 2 green; 2 green, 3 red; 1 blue, 2 red
#  1 red, 2 green
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 3: 1 red, 2 green, 3 blue; 1 red, 2 green; 2 green, 3 red; 1 blue, 2 red
# 2 green
# defaultdict(<class 'int'>, {'red': '1', 'green': '2'})
# Game 3: 1 red, 2 green, 3 blue; 1 red, 2 green; 2 green, 3 red; 1 blue, 2 red
#  2 green, 3 red
# 2 green
# defaultdict(<class 'int'>, {'green': '2'})
# Game 3: 1 red, 2 green, 3 blue; 1 red, 2 green; 2 green, 3 red; 1 blue, 2 red
# 3 red
# defaultdict(<class 'int'>, {'green': '2', 'red': '3'})
# Game 3: 1 red, 2 green, 3 blue; 1 red, 2 green; 2 green, 3 red; 1 blue, 2 red
#  1 blue, 2 red
# 1 blue
# defaultdict(<class 'int'>, {'blue': '1'})
# Game 3: 1 red, 2 green, 3 blue; 1 red, 2 green; 2 green, 3 red; 1 blue, 2 red
# 2 red
# defaultdict(<class 'int'>, {'blue': '1', 'red': '2'})
# Game 3: 1 red, 2 green, 3 blue; 1 red, 2 green; 2 green, 3 red; 1 blue, 2 red
# Game 4: 1 red, 15 green; 1 green, 2 blue; 12 green, 1 red, 2 blue; 14 green; 2 green, 1 blue, 2 red
#  1 red, 15 green
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 4: 1 red, 15 green; 1 green, 2 blue; 12 green, 1 red, 2 blue; 14 green; 2 green, 1 blue, 2 red
# 15 green
# defaultdict(<class 'int'>, {'red': '1', 'green': '15'})
# Game 4: 1 red, 15 green; 1 green, 2 blue; 12 green, 1 red, 2 blue; 14 green; 2 green, 1 blue, 2 red
#  1 green, 2 blue
# 1 green
# defaultdict(<class 'int'>, {'green': '1'})
# Game 4: 1 red, 15 green; 1 green, 2 blue; 12 green, 1 red, 2 blue; 14 green; 2 green, 1 blue, 2 red
# 2 blue
# defaultdict(<class 'int'>, {'green': '1', 'blue': '2'})
# Game 4: 1 red, 15 green; 1 green, 2 blue; 12 green, 1 red, 2 blue; 14 green; 2 green, 1 blue, 2 red
#  12 green, 1 red, 2 blue
# 12 green
# defaultdict(<class 'int'>, {'green': '12'})
# Game 4: 1 red, 15 green; 1 green, 2 blue; 12 green, 1 red, 2 blue; 14 green; 2 green, 1 blue, 2 red
# 1 red
# defaultdict(<class 'int'>, {'green': '12', 'red': '1'})
# Game 4: 1 red, 15 green; 1 green, 2 blue; 12 green, 1 red, 2 blue; 14 green; 2 green, 1 blue, 2 red
# 2 blue
# defaultdict(<class 'int'>, {'green': '12', 'red': '1', 'blue': '2'})
# Game 4: 1 red, 15 green; 1 green, 2 blue; 12 green, 1 red, 2 blue; 14 green; 2 green, 1 blue, 2 red
#  14 green
# 14 green
# defaultdict(<class 'int'>, {'green': '14'})
# Game 4: 1 red, 15 green; 1 green, 2 blue; 12 green, 1 red, 2 blue; 14 green; 2 green, 1 blue, 2 red
#  2 green, 1 blue, 2 red
# 2 green
# defaultdict(<class 'int'>, {'green': '2'})
# Game 4: 1 red, 15 green; 1 green, 2 blue; 12 green, 1 red, 2 blue; 14 green; 2 green, 1 blue, 2 red
# 1 blue
# defaultdict(<class 'int'>, {'green': '2', 'blue': '1'})
# Game 4: 1 red, 15 green; 1 green, 2 blue; 12 green, 1 red, 2 blue; 14 green; 2 green, 1 blue, 2 red
# 2 red
# defaultdict(<class 'int'>, {'green': '2', 'blue': '1', 'red': '2'})
# Game 4: 1 red, 15 green; 1 green, 2 blue; 12 green, 1 red, 2 blue; 14 green; 2 green, 1 blue, 2 red
# Game 5: 8 red; 7 red; 11 red, 4 green; 1 blue, 8 red; 6 red, 2 green, 1 blue; 8 green, 13 red, 1 blue
#  8 red
# 8 red
# defaultdict(<class 'int'>, {'red': '8'})
# Game 5: 8 red; 7 red; 11 red, 4 green; 1 blue, 8 red; 6 red, 2 green, 1 blue; 8 green, 13 red, 1 blue
#  7 red
# 7 red
# defaultdict(<class 'int'>, {'red': '7'})
# Game 5: 8 red; 7 red; 11 red, 4 green; 1 blue, 8 red; 6 red, 2 green, 1 blue; 8 green, 13 red, 1 blue
#  11 red, 4 green
# 11 red
# defaultdict(<class 'int'>, {'red': '11'})
# Game 5: 8 red; 7 red; 11 red, 4 green; 1 blue, 8 red; 6 red, 2 green, 1 blue; 8 green, 13 red, 1 blue
# 4 green
# defaultdict(<class 'int'>, {'red': '11', 'green': '4'})
# Game 5: 8 red; 7 red; 11 red, 4 green; 1 blue, 8 red; 6 red, 2 green, 1 blue; 8 green, 13 red, 1 blue
#  1 blue, 8 red
# 1 blue
# defaultdict(<class 'int'>, {'blue': '1'})
# Game 5: 8 red; 7 red; 11 red, 4 green; 1 blue, 8 red; 6 red, 2 green, 1 blue; 8 green, 13 red, 1 blue
# 8 red
# defaultdict(<class 'int'>, {'blue': '1', 'red': '8'})
# Game 5: 8 red; 7 red; 11 red, 4 green; 1 blue, 8 red; 6 red, 2 green, 1 blue; 8 green, 13 red, 1 blue
#  6 red, 2 green, 1 blue
# 6 red
# defaultdict(<class 'int'>, {'red': '6'})
# Game 5: 8 red; 7 red; 11 red, 4 green; 1 blue, 8 red; 6 red, 2 green, 1 blue; 8 green, 13 red, 1 blue
# 2 green
# defaultdict(<class 'int'>, {'red': '6', 'green': '2'})
# Game 5: 8 red; 7 red; 11 red, 4 green; 1 blue, 8 red; 6 red, 2 green, 1 blue; 8 green, 13 red, 1 blue
# 1 blue
# defaultdict(<class 'int'>, {'red': '6', 'green': '2', 'blue': '1'})
# Game 5: 8 red; 7 red; 11 red, 4 green; 1 blue, 8 red; 6 red, 2 green, 1 blue; 8 green, 13 red, 1 blue
#  8 green, 13 red, 1 blue
# 8 green
# defaultdict(<class 'int'>, {'green': '8'})
# Game 5: 8 red; 7 red; 11 red, 4 green; 1 blue, 8 red; 6 red, 2 green, 1 blue; 8 green, 13 red, 1 blue
# 13 red
# defaultdict(<class 'int'>, {'green': '8', 'red': '13'})
# Game 5: 8 red; 7 red; 11 red, 4 green; 1 blue, 8 red; 6 red, 2 green, 1 blue; 8 green, 13 red, 1 blue
# 1 blue
# defaultdict(<class 'int'>, {'green': '8', 'red': '13', 'blue': '1'})
# Game 5: 8 red; 7 red; 11 red, 4 green; 1 blue, 8 red; 6 red, 2 green, 1 blue; 8 green, 13 red, 1 blue
# Game 6: 3 blue, 2 red, 6 green; 2 red, 8 green, 1 blue; 1 red, 3 blue
#  3 blue, 2 red, 6 green
# 3 blue
# defaultdict(<class 'int'>, {'blue': '3'})
# Game 6: 3 blue, 2 red, 6 green; 2 red, 8 green, 1 blue; 1 red, 3 blue
# 2 red
# defaultdict(<class 'int'>, {'blue': '3', 'red': '2'})
# Game 6: 3 blue, 2 red, 6 green; 2 red, 8 green, 1 blue; 1 red, 3 blue
# 6 green
# defaultdict(<class 'int'>, {'blue': '3', 'red': '2', 'green': '6'})
# Game 6: 3 blue, 2 red, 6 green; 2 red, 8 green, 1 blue; 1 red, 3 blue
#  2 red, 8 green, 1 blue
# 2 red
# defaultdict(<class 'int'>, {'red': '2'})
# Game 6: 3 blue, 2 red, 6 green; 2 red, 8 green, 1 blue; 1 red, 3 blue
# 8 green
# defaultdict(<class 'int'>, {'red': '2', 'green': '8'})
# Game 6: 3 blue, 2 red, 6 green; 2 red, 8 green, 1 blue; 1 red, 3 blue
# 1 blue
# defaultdict(<class 'int'>, {'red': '2', 'green': '8', 'blue': '1'})
# Game 6: 3 blue, 2 red, 6 green; 2 red, 8 green, 1 blue; 1 red, 3 blue
#  1 red, 3 blue
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 6: 3 blue, 2 red, 6 green; 2 red, 8 green, 1 blue; 1 red, 3 blue
# 3 blue
# defaultdict(<class 'int'>, {'red': '1', 'blue': '3'})
# Game 6: 3 blue, 2 red, 6 green; 2 red, 8 green, 1 blue; 1 red, 3 blue
# Game 7: 5 green, 1 red, 1 blue; 6 blue, 12 red; 6 red, 7 green; 3 green, 1 blue
#  5 green, 1 red, 1 blue
# 5 green
# defaultdict(<class 'int'>, {'green': '5'})
# Game 7: 5 green, 1 red, 1 blue; 6 blue, 12 red; 6 red, 7 green; 3 green, 1 blue
# 1 red
# defaultdict(<class 'int'>, {'green': '5', 'red': '1'})
# Game 7: 5 green, 1 red, 1 blue; 6 blue, 12 red; 6 red, 7 green; 3 green, 1 blue
# 1 blue
# defaultdict(<class 'int'>, {'green': '5', 'red': '1', 'blue': '1'})
# Game 7: 5 green, 1 red, 1 blue; 6 blue, 12 red; 6 red, 7 green; 3 green, 1 blue
#  6 blue, 12 red
# 6 blue
# defaultdict(<class 'int'>, {'blue': '6'})
# Game 7: 5 green, 1 red, 1 blue; 6 blue, 12 red; 6 red, 7 green; 3 green, 1 blue
# 12 red
# defaultdict(<class 'int'>, {'blue': '6', 'red': '12'})
# Game 7: 5 green, 1 red, 1 blue; 6 blue, 12 red; 6 red, 7 green; 3 green, 1 blue
#  6 red, 7 green
# 6 red
# defaultdict(<class 'int'>, {'red': '6'})
# Game 7: 5 green, 1 red, 1 blue; 6 blue, 12 red; 6 red, 7 green; 3 green, 1 blue
# 7 green
# defaultdict(<class 'int'>, {'red': '6', 'green': '7'})
# Game 7: 5 green, 1 red, 1 blue; 6 blue, 12 red; 6 red, 7 green; 3 green, 1 blue
#  3 green, 1 blue
# 3 green
# defaultdict(<class 'int'>, {'green': '3'})
# Game 7: 5 green, 1 red, 1 blue; 6 blue, 12 red; 6 red, 7 green; 3 green, 1 blue
# 1 blue
# defaultdict(<class 'int'>, {'green': '3', 'blue': '1'})
# Game 7: 5 green, 1 red, 1 blue; 6 blue, 12 red; 6 red, 7 green; 3 green, 1 blue
# Game 8: 10 red, 6 green; 4 blue, 6 green, 5 red; 8 green, 5 red, 5 blue; 2 red, 4 blue
#  10 red, 6 green
# 10 red
# defaultdict(<class 'int'>, {'red': '10'})
# Game 8: 10 red, 6 green; 4 blue, 6 green, 5 red; 8 green, 5 red, 5 blue; 2 red, 4 blue
# 6 green
# defaultdict(<class 'int'>, {'red': '10', 'green': '6'})
# Game 8: 10 red, 6 green; 4 blue, 6 green, 5 red; 8 green, 5 red, 5 blue; 2 red, 4 blue
#  4 blue, 6 green, 5 red
# 4 blue
# defaultdict(<class 'int'>, {'blue': '4'})
# Game 8: 10 red, 6 green; 4 blue, 6 green, 5 red; 8 green, 5 red, 5 blue; 2 red, 4 blue
# 6 green
# defaultdict(<class 'int'>, {'blue': '4', 'green': '6'})
# Game 8: 10 red, 6 green; 4 blue, 6 green, 5 red; 8 green, 5 red, 5 blue; 2 red, 4 blue
# 5 red
# defaultdict(<class 'int'>, {'blue': '4', 'green': '6', 'red': '5'})
# Game 8: 10 red, 6 green; 4 blue, 6 green, 5 red; 8 green, 5 red, 5 blue; 2 red, 4 blue
#  8 green, 5 red, 5 blue
# 8 green
# defaultdict(<class 'int'>, {'green': '8'})
# Game 8: 10 red, 6 green; 4 blue, 6 green, 5 red; 8 green, 5 red, 5 blue; 2 red, 4 blue
# 5 red
# defaultdict(<class 'int'>, {'green': '8', 'red': '5'})
# Game 8: 10 red, 6 green; 4 blue, 6 green, 5 red; 8 green, 5 red, 5 blue; 2 red, 4 blue
# 5 blue
# defaultdict(<class 'int'>, {'green': '8', 'red': '5', 'blue': '5'})
# Game 8: 10 red, 6 green; 4 blue, 6 green, 5 red; 8 green, 5 red, 5 blue; 2 red, 4 blue
#  2 red, 4 blue
# 2 red
# defaultdict(<class 'int'>, {'red': '2'})
# Game 8: 10 red, 6 green; 4 blue, 6 green, 5 red; 8 green, 5 red, 5 blue; 2 red, 4 blue
# 4 blue
# defaultdict(<class 'int'>, {'red': '2', 'blue': '4'})
# Game 8: 10 red, 6 green; 4 blue, 6 green, 5 red; 8 green, 5 red, 5 blue; 2 red, 4 blue
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
#  11 blue, 13 red, 3 green
# 11 blue
# defaultdict(<class 'int'>, {'blue': '11'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
# 13 red
# defaultdict(<class 'int'>, {'blue': '11', 'red': '13'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
# 3 green
# defaultdict(<class 'int'>, {'blue': '11', 'red': '13', 'green': '3'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
#  13 red, 1 green, 6 blue
# 13 red
# defaultdict(<class 'int'>, {'red': '13'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
# 1 green
# defaultdict(<class 'int'>, {'red': '13', 'green': '1'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
# 6 blue
# defaultdict(<class 'int'>, {'red': '13', 'green': '1', 'blue': '6'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
#  8 blue, 4 green, 5 red
# 8 blue
# defaultdict(<class 'int'>, {'blue': '8'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
# 4 green
# defaultdict(<class 'int'>, {'blue': '8', 'green': '4'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
# 5 red
# defaultdict(<class 'int'>, {'blue': '8', 'green': '4', 'red': '5'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
#  16 red, 7 green, 10 blue
# 16 red
# defaultdict(<class 'int'>, {'red': '16'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
# 7 green
# defaultdict(<class 'int'>, {'red': '16', 'green': '7'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
# 10 blue
# defaultdict(<class 'int'>, {'red': '16', 'green': '7', 'blue': '10'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
#  16 red, 5 green, 6 blue
# 16 red
# defaultdict(<class 'int'>, {'red': '16'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
# 5 green
# defaultdict(<class 'int'>, {'red': '16', 'green': '5'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
# 6 blue
# defaultdict(<class 'int'>, {'red': '16', 'green': '5', 'blue': '6'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
#  17 red, 6 blue
# 17 red
# defaultdict(<class 'int'>, {'red': '17'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
# 6 blue
# defaultdict(<class 'int'>, {'red': '17', 'blue': '6'})
# Game 9: 11 blue, 13 red, 3 green; 13 red, 1 green, 6 blue; 8 blue, 4 green, 5 red; 16 red, 7 green, 10 blue; 16 red, 5 green, 6 blue; 17 red, 6 blue
# Game 10: 16 blue, 8 green; 2 red, 4 green, 1 blue; 15 blue; 4 red, 5 green, 4 blue
#  16 blue, 8 green
# 16 blue
# defaultdict(<class 'int'>, {'blue': '16'})
# Game 10: 16 blue, 8 green; 2 red, 4 green, 1 blue; 15 blue; 4 red, 5 green, 4 blue
# 8 green
# defaultdict(<class 'int'>, {'blue': '16', 'green': '8'})
# Game 10: 16 blue, 8 green; 2 red, 4 green, 1 blue; 15 blue; 4 red, 5 green, 4 blue
#  2 red, 4 green, 1 blue
# 2 red
# defaultdict(<class 'int'>, {'red': '2'})
# Game 10: 16 blue, 8 green; 2 red, 4 green, 1 blue; 15 blue; 4 red, 5 green, 4 blue
# 4 green
# defaultdict(<class 'int'>, {'red': '2', 'green': '4'})
# Game 10: 16 blue, 8 green; 2 red, 4 green, 1 blue; 15 blue; 4 red, 5 green, 4 blue
# 1 blue
# defaultdict(<class 'int'>, {'red': '2', 'green': '4', 'blue': '1'})
# Game 10: 16 blue, 8 green; 2 red, 4 green, 1 blue; 15 blue; 4 red, 5 green, 4 blue
#  15 blue
# 15 blue
# defaultdict(<class 'int'>, {'blue': '15'})
# Game 10: 16 blue, 8 green; 2 red, 4 green, 1 blue; 15 blue; 4 red, 5 green, 4 blue
#  4 red, 5 green, 4 blue
# 4 red
# defaultdict(<class 'int'>, {'red': '4'})
# Game 10: 16 blue, 8 green; 2 red, 4 green, 1 blue; 15 blue; 4 red, 5 green, 4 blue
# 5 green
# defaultdict(<class 'int'>, {'red': '4', 'green': '5'})
# Game 10: 16 blue, 8 green; 2 red, 4 green, 1 blue; 15 blue; 4 red, 5 green, 4 blue
# 4 blue
# defaultdict(<class 'int'>, {'red': '4', 'green': '5', 'blue': '4'})
# Game 10: 16 blue, 8 green; 2 red, 4 green, 1 blue; 15 blue; 4 red, 5 green, 4 blue
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
#  3 blue, 8 red, 10 green
# 3 blue
# defaultdict(<class 'int'>, {'blue': '3'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
# 8 red
# defaultdict(<class 'int'>, {'blue': '3', 'red': '8'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
# 10 green
# defaultdict(<class 'int'>, {'blue': '3', 'red': '8', 'green': '10'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
#  10 red, 6 green
# 10 red
# defaultdict(<class 'int'>, {'red': '10'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
# 6 green
# defaultdict(<class 'int'>, {'red': '10', 'green': '6'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
#  1 red, 1 green
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
# 1 green
# defaultdict(<class 'int'>, {'red': '1', 'green': '1'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
#  13 red, 1 green, 1 blue
# 13 red
# defaultdict(<class 'int'>, {'red': '13'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
# 1 green
# defaultdict(<class 'int'>, {'red': '13', 'green': '1'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
# 1 blue
# defaultdict(<class 'int'>, {'red': '13', 'green': '1', 'blue': '1'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
#  3 green, 7 red
# 3 green
# defaultdict(<class 'int'>, {'green': '3'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
# 7 red
# defaultdict(<class 'int'>, {'green': '3', 'red': '7'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
#  2 blue, 6 green, 2 red
# 2 blue
# defaultdict(<class 'int'>, {'blue': '2'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
# 6 green
# defaultdict(<class 'int'>, {'blue': '2', 'green': '6'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
# 2 red
# defaultdict(<class 'int'>, {'blue': '2', 'green': '6', 'red': '2'})
# Game 11: 3 blue, 8 red, 10 green; 10 red, 6 green; 1 red, 1 green; 13 red, 1 green, 1 blue; 3 green, 7 red; 2 blue, 6 green, 2 red
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
#  1 red, 10 green
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
# 10 green
# defaultdict(<class 'int'>, {'red': '1', 'green': '10'})
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
#  4 red, 6 green, 1 blue
# 4 red
# defaultdict(<class 'int'>, {'red': '4'})
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
# 6 green
# defaultdict(<class 'int'>, {'red': '4', 'green': '6'})
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
# 1 blue
# defaultdict(<class 'int'>, {'red': '4', 'green': '6', 'blue': '1'})
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
#  9 green, 1 blue, 7 red
# 9 green
# defaultdict(<class 'int'>, {'green': '9'})
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
# 1 blue
# defaultdict(<class 'int'>, {'green': '9', 'blue': '1'})
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
# 7 red
# defaultdict(<class 'int'>, {'green': '9', 'blue': '1', 'red': '7'})
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
#  1 blue, 13 green, 2 red
# 1 blue
# defaultdict(<class 'int'>, {'blue': '1'})
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
# 13 green
# defaultdict(<class 'int'>, {'blue': '1', 'green': '13'})
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
# 2 red
# defaultdict(<class 'int'>, {'blue': '1', 'green': '13', 'red': '2'})
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
#  2 blue, 5 red, 11 green
# 2 blue
# defaultdict(<class 'int'>, {'blue': '2'})
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
# 5 red
# defaultdict(<class 'int'>, {'blue': '2', 'red': '5'})
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
# 11 green
# defaultdict(<class 'int'>, {'blue': '2', 'red': '5', 'green': '11'})
# Game 12: 1 red, 10 green; 4 red, 6 green, 1 blue; 9 green, 1 blue, 7 red; 1 blue, 13 green, 2 red; 2 blue, 5 red, 11 green
# Game 13: 1 red, 5 blue; 1 red, 6 green; 2 blue, 1 red; 2 blue, 1 red, 2 green; 5 green, 2 blue
#  1 red, 5 blue
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 13: 1 red, 5 blue; 1 red, 6 green; 2 blue, 1 red; 2 blue, 1 red, 2 green; 5 green, 2 blue
# 5 blue
# defaultdict(<class 'int'>, {'red': '1', 'blue': '5'})
# Game 13: 1 red, 5 blue; 1 red, 6 green; 2 blue, 1 red; 2 blue, 1 red, 2 green; 5 green, 2 blue
#  1 red, 6 green
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 13: 1 red, 5 blue; 1 red, 6 green; 2 blue, 1 red; 2 blue, 1 red, 2 green; 5 green, 2 blue
# 6 green
# defaultdict(<class 'int'>, {'red': '1', 'green': '6'})
# Game 13: 1 red, 5 blue; 1 red, 6 green; 2 blue, 1 red; 2 blue, 1 red, 2 green; 5 green, 2 blue
#  2 blue, 1 red
# 2 blue
# defaultdict(<class 'int'>, {'blue': '2'})
# Game 13: 1 red, 5 blue; 1 red, 6 green; 2 blue, 1 red; 2 blue, 1 red, 2 green; 5 green, 2 blue
# 1 red
# defaultdict(<class 'int'>, {'blue': '2', 'red': '1'})
# Game 13: 1 red, 5 blue; 1 red, 6 green; 2 blue, 1 red; 2 blue, 1 red, 2 green; 5 green, 2 blue
#  2 blue, 1 red, 2 green
# 2 blue
# defaultdict(<class 'int'>, {'blue': '2'})
# Game 13: 1 red, 5 blue; 1 red, 6 green; 2 blue, 1 red; 2 blue, 1 red, 2 green; 5 green, 2 blue
# 1 red
# defaultdict(<class 'int'>, {'blue': '2', 'red': '1'})
# Game 13: 1 red, 5 blue; 1 red, 6 green; 2 blue, 1 red; 2 blue, 1 red, 2 green; 5 green, 2 blue
# 2 green
# defaultdict(<class 'int'>, {'blue': '2', 'red': '1', 'green': '2'})
# Game 13: 1 red, 5 blue; 1 red, 6 green; 2 blue, 1 red; 2 blue, 1 red, 2 green; 5 green, 2 blue
#  5 green, 2 blue
# 5 green
# defaultdict(<class 'int'>, {'green': '5'})
# Game 13: 1 red, 5 blue; 1 red, 6 green; 2 blue, 1 red; 2 blue, 1 red, 2 green; 5 green, 2 blue
# 2 blue
# defaultdict(<class 'int'>, {'green': '5', 'blue': '2'})
# Game 13: 1 red, 5 blue; 1 red, 6 green; 2 blue, 1 red; 2 blue, 1 red, 2 green; 5 green, 2 blue
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
#  4 green
# 4 green
# defaultdict(<class 'int'>, {'green': '4'})
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
#  8 blue, 1 red, 2 green
# 8 blue
# defaultdict(<class 'int'>, {'blue': '8'})
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
# 1 red
# defaultdict(<class 'int'>, {'blue': '8', 'red': '1'})
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
# 2 green
# defaultdict(<class 'int'>, {'blue': '8', 'red': '1', 'green': '2'})
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
#  7 red, 2 green, 4 blue
# 7 red
# defaultdict(<class 'int'>, {'red': '7'})
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
# 2 green
# defaultdict(<class 'int'>, {'red': '7', 'green': '2'})
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
# 4 blue
# defaultdict(<class 'int'>, {'red': '7', 'green': '2', 'blue': '4'})
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
#  4 blue, 7 green
# 4 blue
# defaultdict(<class 'int'>, {'blue': '4'})
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
# 7 green
# defaultdict(<class 'int'>, {'blue': '4', 'green': '7'})
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
#  7 blue, 2 green, 1 red
# 7 blue
# defaultdict(<class 'int'>, {'blue': '7'})
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
# 2 green
# defaultdict(<class 'int'>, {'blue': '7', 'green': '2'})
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
# 1 red
# defaultdict(<class 'int'>, {'blue': '7', 'green': '2', 'red': '1'})
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
#  7 blue, 5 red
# 7 blue
# defaultdict(<class 'int'>, {'blue': '7'})
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
# 5 red
# defaultdict(<class 'int'>, {'blue': '7', 'red': '5'})
# Game 14: 4 green; 8 blue, 1 red, 2 green; 7 red, 2 green, 4 blue; 4 blue, 7 green; 7 blue, 2 green, 1 red; 7 blue, 5 red
# Game 15: 10 green, 3 red; 8 blue, 14 green, 3 red; 4 red, 1 green, 12 blue
#  10 green, 3 red
# 10 green
# defaultdict(<class 'int'>, {'green': '10'})
# Game 15: 10 green, 3 red; 8 blue, 14 green, 3 red; 4 red, 1 green, 12 blue
# 3 red
# defaultdict(<class 'int'>, {'green': '10', 'red': '3'})
# Game 15: 10 green, 3 red; 8 blue, 14 green, 3 red; 4 red, 1 green, 12 blue
#  8 blue, 14 green, 3 red
# 8 blue
# defaultdict(<class 'int'>, {'blue': '8'})
# Game 15: 10 green, 3 red; 8 blue, 14 green, 3 red; 4 red, 1 green, 12 blue
# 14 green
# defaultdict(<class 'int'>, {'blue': '8', 'green': '14'})
# Game 15: 10 green, 3 red; 8 blue, 14 green, 3 red; 4 red, 1 green, 12 blue
# 3 red
# defaultdict(<class 'int'>, {'blue': '8', 'green': '14', 'red': '3'})
# Game 15: 10 green, 3 red; 8 blue, 14 green, 3 red; 4 red, 1 green, 12 blue
#  4 red, 1 green, 12 blue
# 4 red
# defaultdict(<class 'int'>, {'red': '4'})
# Game 15: 10 green, 3 red; 8 blue, 14 green, 3 red; 4 red, 1 green, 12 blue
# 1 green
# defaultdict(<class 'int'>, {'red': '4', 'green': '1'})
# Game 15: 10 green, 3 red; 8 blue, 14 green, 3 red; 4 red, 1 green, 12 blue
# 12 blue
# defaultdict(<class 'int'>, {'red': '4', 'green': '1', 'blue': '12'})
# Game 15: 10 green, 3 red; 8 blue, 14 green, 3 red; 4 red, 1 green, 12 blue
# Game 16: 8 red, 4 blue, 6 green; 14 blue, 9 red, 10 green; 1 red, 5 blue, 8 green; 14 blue, 11 green, 3 red
#  8 red, 4 blue, 6 green
# 8 red
# defaultdict(<class 'int'>, {'red': '8'})
# Game 16: 8 red, 4 blue, 6 green; 14 blue, 9 red, 10 green; 1 red, 5 blue, 8 green; 14 blue, 11 green, 3 red
# 4 blue
# defaultdict(<class 'int'>, {'red': '8', 'blue': '4'})
# Game 16: 8 red, 4 blue, 6 green; 14 blue, 9 red, 10 green; 1 red, 5 blue, 8 green; 14 blue, 11 green, 3 red
# 6 green
# defaultdict(<class 'int'>, {'red': '8', 'blue': '4', 'green': '6'})
# Game 16: 8 red, 4 blue, 6 green; 14 blue, 9 red, 10 green; 1 red, 5 blue, 8 green; 14 blue, 11 green, 3 red
#  14 blue, 9 red, 10 green
# 14 blue
# defaultdict(<class 'int'>, {'blue': '14'})
# Game 16: 8 red, 4 blue, 6 green; 14 blue, 9 red, 10 green; 1 red, 5 blue, 8 green; 14 blue, 11 green, 3 red
# 9 red
# defaultdict(<class 'int'>, {'blue': '14', 'red': '9'})
# Game 16: 8 red, 4 blue, 6 green; 14 blue, 9 red, 10 green; 1 red, 5 blue, 8 green; 14 blue, 11 green, 3 red
# 10 green
# defaultdict(<class 'int'>, {'blue': '14', 'red': '9', 'green': '10'})
# Game 16: 8 red, 4 blue, 6 green; 14 blue, 9 red, 10 green; 1 red, 5 blue, 8 green; 14 blue, 11 green, 3 red
#  1 red, 5 blue, 8 green
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 16: 8 red, 4 blue, 6 green; 14 blue, 9 red, 10 green; 1 red, 5 blue, 8 green; 14 blue, 11 green, 3 red
# 5 blue
# defaultdict(<class 'int'>, {'red': '1', 'blue': '5'})
# Game 16: 8 red, 4 blue, 6 green; 14 blue, 9 red, 10 green; 1 red, 5 blue, 8 green; 14 blue, 11 green, 3 red
# 8 green
# defaultdict(<class 'int'>, {'red': '1', 'blue': '5', 'green': '8'})
# Game 16: 8 red, 4 blue, 6 green; 14 blue, 9 red, 10 green; 1 red, 5 blue, 8 green; 14 blue, 11 green, 3 red
#  14 blue, 11 green, 3 red
# 14 blue
# defaultdict(<class 'int'>, {'blue': '14'})
# Game 16: 8 red, 4 blue, 6 green; 14 blue, 9 red, 10 green; 1 red, 5 blue, 8 green; 14 blue, 11 green, 3 red
# 11 green
# defaultdict(<class 'int'>, {'blue': '14', 'green': '11'})
# Game 16: 8 red, 4 blue, 6 green; 14 blue, 9 red, 10 green; 1 red, 5 blue, 8 green; 14 blue, 11 green, 3 red
# 3 red
# defaultdict(<class 'int'>, {'blue': '14', 'green': '11', 'red': '3'})
# Game 16: 8 red, 4 blue, 6 green; 14 blue, 9 red, 10 green; 1 red, 5 blue, 8 green; 14 blue, 11 green, 3 red
# Game 17: 20 blue, 5 red, 4 green; 3 red, 14 blue; 4 red, 4 blue, 4 green; 12 blue, 5 red, 3 green
#  20 blue, 5 red, 4 green
# 20 blue
# defaultdict(<class 'int'>, {'blue': '20'})
# Game 17: 20 blue, 5 red, 4 green; 3 red, 14 blue; 4 red, 4 blue, 4 green; 12 blue, 5 red, 3 green
# 5 red
# defaultdict(<class 'int'>, {'blue': '20', 'red': '5'})
# Game 17: 20 blue, 5 red, 4 green; 3 red, 14 blue; 4 red, 4 blue, 4 green; 12 blue, 5 red, 3 green
# 4 green
# defaultdict(<class 'int'>, {'blue': '20', 'red': '5', 'green': '4'})
# Game 17: 20 blue, 5 red, 4 green; 3 red, 14 blue; 4 red, 4 blue, 4 green; 12 blue, 5 red, 3 green
#  3 red, 14 blue
# 3 red
# defaultdict(<class 'int'>, {'red': '3'})
# Game 17: 20 blue, 5 red, 4 green; 3 red, 14 blue; 4 red, 4 blue, 4 green; 12 blue, 5 red, 3 green
# 14 blue
# defaultdict(<class 'int'>, {'red': '3', 'blue': '14'})
# Game 17: 20 blue, 5 red, 4 green; 3 red, 14 blue; 4 red, 4 blue, 4 green; 12 blue, 5 red, 3 green
#  4 red, 4 blue, 4 green
# 4 red
# defaultdict(<class 'int'>, {'red': '4'})
# Game 17: 20 blue, 5 red, 4 green; 3 red, 14 blue; 4 red, 4 blue, 4 green; 12 blue, 5 red, 3 green
# 4 blue
# defaultdict(<class 'int'>, {'red': '4', 'blue': '4'})
# Game 17: 20 blue, 5 red, 4 green; 3 red, 14 blue; 4 red, 4 blue, 4 green; 12 blue, 5 red, 3 green
# 4 green
# defaultdict(<class 'int'>, {'red': '4', 'blue': '4', 'green': '4'})
# Game 17: 20 blue, 5 red, 4 green; 3 red, 14 blue; 4 red, 4 blue, 4 green; 12 blue, 5 red, 3 green
#  12 blue, 5 red, 3 green
# 12 blue
# defaultdict(<class 'int'>, {'blue': '12'})
# Game 17: 20 blue, 5 red, 4 green; 3 red, 14 blue; 4 red, 4 blue, 4 green; 12 blue, 5 red, 3 green
# 5 red
# defaultdict(<class 'int'>, {'blue': '12', 'red': '5'})
# Game 17: 20 blue, 5 red, 4 green; 3 red, 14 blue; 4 red, 4 blue, 4 green; 12 blue, 5 red, 3 green
# 3 green
# defaultdict(<class 'int'>, {'blue': '12', 'red': '5', 'green': '3'})
# Game 17: 20 blue, 5 red, 4 green; 3 red, 14 blue; 4 red, 4 blue, 4 green; 12 blue, 5 red, 3 green
# Game 18: 7 blue, 8 red; 1 blue, 2 red; 1 green, 2 blue
#  7 blue, 8 red
# 7 blue
# defaultdict(<class 'int'>, {'blue': '7'})
# Game 18: 7 blue, 8 red; 1 blue, 2 red; 1 green, 2 blue
# 8 red
# defaultdict(<class 'int'>, {'blue': '7', 'red': '8'})
# Game 18: 7 blue, 8 red; 1 blue, 2 red; 1 green, 2 blue
#  1 blue, 2 red
# 1 blue
# defaultdict(<class 'int'>, {'blue': '1'})
# Game 18: 7 blue, 8 red; 1 blue, 2 red; 1 green, 2 blue
# 2 red
# defaultdict(<class 'int'>, {'blue': '1', 'red': '2'})
# Game 18: 7 blue, 8 red; 1 blue, 2 red; 1 green, 2 blue
#  1 green, 2 blue
# 1 green
# defaultdict(<class 'int'>, {'green': '1'})
# Game 18: 7 blue, 8 red; 1 blue, 2 red; 1 green, 2 blue
# 2 blue
# defaultdict(<class 'int'>, {'green': '1', 'blue': '2'})
# Game 18: 7 blue, 8 red; 1 blue, 2 red; 1 green, 2 blue
# Game 19: 14 green, 4 blue; 6 green; 12 green, 5 blue; 12 green, 1 red, 1 blue; 4 blue, 10 green
#  14 green, 4 blue
# 14 green
# defaultdict(<class 'int'>, {'green': '14'})
# Game 19: 14 green, 4 blue; 6 green; 12 green, 5 blue; 12 green, 1 red, 1 blue; 4 blue, 10 green
# 4 blue
# defaultdict(<class 'int'>, {'green': '14', 'blue': '4'})
# Game 19: 14 green, 4 blue; 6 green; 12 green, 5 blue; 12 green, 1 red, 1 blue; 4 blue, 10 green
#  6 green
# 6 green
# defaultdict(<class 'int'>, {'green': '6'})
# Game 19: 14 green, 4 blue; 6 green; 12 green, 5 blue; 12 green, 1 red, 1 blue; 4 blue, 10 green
#  12 green, 5 blue
# 12 green
# defaultdict(<class 'int'>, {'green': '12'})
# Game 19: 14 green, 4 blue; 6 green; 12 green, 5 blue; 12 green, 1 red, 1 blue; 4 blue, 10 green
# 5 blue
# defaultdict(<class 'int'>, {'green': '12', 'blue': '5'})
# Game 19: 14 green, 4 blue; 6 green; 12 green, 5 blue; 12 green, 1 red, 1 blue; 4 blue, 10 green
#  12 green, 1 red, 1 blue
# 12 green
# defaultdict(<class 'int'>, {'green': '12'})
# Game 19: 14 green, 4 blue; 6 green; 12 green, 5 blue; 12 green, 1 red, 1 blue; 4 blue, 10 green
# 1 red
# defaultdict(<class 'int'>, {'green': '12', 'red': '1'})
# Game 19: 14 green, 4 blue; 6 green; 12 green, 5 blue; 12 green, 1 red, 1 blue; 4 blue, 10 green
# 1 blue
# defaultdict(<class 'int'>, {'green': '12', 'red': '1', 'blue': '1'})
# Game 19: 14 green, 4 blue; 6 green; 12 green, 5 blue; 12 green, 1 red, 1 blue; 4 blue, 10 green
#  4 blue, 10 green
# 4 blue
# defaultdict(<class 'int'>, {'blue': '4'})
# Game 19: 14 green, 4 blue; 6 green; 12 green, 5 blue; 12 green, 1 red, 1 blue; 4 blue, 10 green
# 10 green
# defaultdict(<class 'int'>, {'blue': '4', 'green': '10'})
# Game 19: 14 green, 4 blue; 6 green; 12 green, 5 blue; 12 green, 1 red, 1 blue; 4 blue, 10 green
# Game 20: 3 green, 4 blue, 4 red; 13 blue, 1 red, 2 green; 13 blue, 9 green, 9 red
#  3 green, 4 blue, 4 red
# 3 green
# defaultdict(<class 'int'>, {'green': '3'})
# Game 20: 3 green, 4 blue, 4 red; 13 blue, 1 red, 2 green; 13 blue, 9 green, 9 red
# 4 blue
# defaultdict(<class 'int'>, {'green': '3', 'blue': '4'})
# Game 20: 3 green, 4 blue, 4 red; 13 blue, 1 red, 2 green; 13 blue, 9 green, 9 red
# 4 red
# defaultdict(<class 'int'>, {'green': '3', 'blue': '4', 'red': '4'})
# Game 20: 3 green, 4 blue, 4 red; 13 blue, 1 red, 2 green; 13 blue, 9 green, 9 red
#  13 blue, 1 red, 2 green
# 13 blue
# defaultdict(<class 'int'>, {'blue': '13'})
# Game 20: 3 green, 4 blue, 4 red; 13 blue, 1 red, 2 green; 13 blue, 9 green, 9 red
# 1 red
# defaultdict(<class 'int'>, {'blue': '13', 'red': '1'})
# Game 20: 3 green, 4 blue, 4 red; 13 blue, 1 red, 2 green; 13 blue, 9 green, 9 red
# 2 green
# defaultdict(<class 'int'>, {'blue': '13', 'red': '1', 'green': '2'})
# Game 20: 3 green, 4 blue, 4 red; 13 blue, 1 red, 2 green; 13 blue, 9 green, 9 red
#  13 blue, 9 green, 9 red
# 13 blue
# defaultdict(<class 'int'>, {'blue': '13'})
# Game 20: 3 green, 4 blue, 4 red; 13 blue, 1 red, 2 green; 13 blue, 9 green, 9 red
# 9 green
# defaultdict(<class 'int'>, {'blue': '13', 'green': '9'})
# Game 20: 3 green, 4 blue, 4 red; 13 blue, 1 red, 2 green; 13 blue, 9 green, 9 red
# 9 red
# defaultdict(<class 'int'>, {'blue': '13', 'green': '9', 'red': '9'})
# Game 20: 3 green, 4 blue, 4 red; 13 blue, 1 red, 2 green; 13 blue, 9 green, 9 red
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
#  4 green, 2 blue, 2 red
# 4 green
# defaultdict(<class 'int'>, {'green': '4'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
# 2 blue
# defaultdict(<class 'int'>, {'green': '4', 'blue': '2'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
# 2 red
# defaultdict(<class 'int'>, {'green': '4', 'blue': '2', 'red': '2'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
#  3 green, 2 blue
# 3 green
# defaultdict(<class 'int'>, {'green': '3'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
# 2 blue
# defaultdict(<class 'int'>, {'green': '3', 'blue': '2'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
#  1 blue, 5 green
# 1 blue
# defaultdict(<class 'int'>, {'blue': '1'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
# 5 green
# defaultdict(<class 'int'>, {'blue': '1', 'green': '5'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
#  1 blue, 2 red, 3 green
# 1 blue
# defaultdict(<class 'int'>, {'blue': '1'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
# 2 red
# defaultdict(<class 'int'>, {'blue': '1', 'red': '2'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
# 3 green
# defaultdict(<class 'int'>, {'blue': '1', 'red': '2', 'green': '3'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
#  1 green, 1 blue, 2 red
# 1 green
# defaultdict(<class 'int'>, {'green': '1'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
# 1 blue
# defaultdict(<class 'int'>, {'green': '1', 'blue': '1'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
# 2 red
# defaultdict(<class 'int'>, {'green': '1', 'blue': '1', 'red': '2'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
#  6 blue, 1 green
# 6 blue
# defaultdict(<class 'int'>, {'blue': '6'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
# 1 green
# defaultdict(<class 'int'>, {'blue': '6', 'green': '1'})
# Game 21: 4 green, 2 blue, 2 red; 3 green, 2 blue; 1 blue, 5 green; 1 blue, 2 red, 3 green; 1 green, 1 blue, 2 red; 6 blue, 1 green
# Game 22: 4 red, 17 green; 15 green, 3 blue, 2 red; 4 blue, 7 red, 11 green; 16 green, 4 red; 3 blue, 2 red
#  4 red, 17 green
# 4 red
# defaultdict(<class 'int'>, {'red': '4'})
# Game 22: 4 red, 17 green; 15 green, 3 blue, 2 red; 4 blue, 7 red, 11 green; 16 green, 4 red; 3 blue, 2 red
# 17 green
# defaultdict(<class 'int'>, {'red': '4', 'green': '17'})
# Game 22: 4 red, 17 green; 15 green, 3 blue, 2 red; 4 blue, 7 red, 11 green; 16 green, 4 red; 3 blue, 2 red
#  15 green, 3 blue, 2 red
# 15 green
# defaultdict(<class 'int'>, {'green': '15'})
# Game 22: 4 red, 17 green; 15 green, 3 blue, 2 red; 4 blue, 7 red, 11 green; 16 green, 4 red; 3 blue, 2 red
# 3 blue
# defaultdict(<class 'int'>, {'green': '15', 'blue': '3'})
# Game 22: 4 red, 17 green; 15 green, 3 blue, 2 red; 4 blue, 7 red, 11 green; 16 green, 4 red; 3 blue, 2 red
# 2 red
# defaultdict(<class 'int'>, {'green': '15', 'blue': '3', 'red': '2'})
# Game 22: 4 red, 17 green; 15 green, 3 blue, 2 red; 4 blue, 7 red, 11 green; 16 green, 4 red; 3 blue, 2 red
#  4 blue, 7 red, 11 green
# 4 blue
# defaultdict(<class 'int'>, {'blue': '4'})
# Game 22: 4 red, 17 green; 15 green, 3 blue, 2 red; 4 blue, 7 red, 11 green; 16 green, 4 red; 3 blue, 2 red
# 7 red
# defaultdict(<class 'int'>, {'blue': '4', 'red': '7'})
# Game 22: 4 red, 17 green; 15 green, 3 blue, 2 red; 4 blue, 7 red, 11 green; 16 green, 4 red; 3 blue, 2 red
# 11 green
# defaultdict(<class 'int'>, {'blue': '4', 'red': '7', 'green': '11'})
# Game 22: 4 red, 17 green; 15 green, 3 blue, 2 red; 4 blue, 7 red, 11 green; 16 green, 4 red; 3 blue, 2 red
#  16 green, 4 red
# 16 green
# defaultdict(<class 'int'>, {'green': '16'})
# Game 22: 4 red, 17 green; 15 green, 3 blue, 2 red; 4 blue, 7 red, 11 green; 16 green, 4 red; 3 blue, 2 red
# 4 red
# defaultdict(<class 'int'>, {'green': '16', 'red': '4'})
# Game 22: 4 red, 17 green; 15 green, 3 blue, 2 red; 4 blue, 7 red, 11 green; 16 green, 4 red; 3 blue, 2 red
#  3 blue, 2 red
# 3 blue
# defaultdict(<class 'int'>, {'blue': '3'})
# Game 22: 4 red, 17 green; 15 green, 3 blue, 2 red; 4 blue, 7 red, 11 green; 16 green, 4 red; 3 blue, 2 red
# 2 red
# defaultdict(<class 'int'>, {'blue': '3', 'red': '2'})
# Game 22: 4 red, 17 green; 15 green, 3 blue, 2 red; 4 blue, 7 red, 11 green; 16 green, 4 red; 3 blue, 2 red
# Game 23: 19 green, 2 blue, 3 red; 1 red, 2 blue, 2 green; 2 blue, 10 green, 11 red
#  19 green, 2 blue, 3 red
# 19 green
# defaultdict(<class 'int'>, {'green': '19'})
# Game 23: 19 green, 2 blue, 3 red; 1 red, 2 blue, 2 green; 2 blue, 10 green, 11 red
# 2 blue
# defaultdict(<class 'int'>, {'green': '19', 'blue': '2'})
# Game 23: 19 green, 2 blue, 3 red; 1 red, 2 blue, 2 green; 2 blue, 10 green, 11 red
# 3 red
# defaultdict(<class 'int'>, {'green': '19', 'blue': '2', 'red': '3'})
# Game 23: 19 green, 2 blue, 3 red; 1 red, 2 blue, 2 green; 2 blue, 10 green, 11 red
#  1 red, 2 blue, 2 green
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 23: 19 green, 2 blue, 3 red; 1 red, 2 blue, 2 green; 2 blue, 10 green, 11 red
# 2 blue
# defaultdict(<class 'int'>, {'red': '1', 'blue': '2'})
# Game 23: 19 green, 2 blue, 3 red; 1 red, 2 blue, 2 green; 2 blue, 10 green, 11 red
# 2 green
# defaultdict(<class 'int'>, {'red': '1', 'blue': '2', 'green': '2'})
# Game 23: 19 green, 2 blue, 3 red; 1 red, 2 blue, 2 green; 2 blue, 10 green, 11 red
#  2 blue, 10 green, 11 red
# 2 blue
# defaultdict(<class 'int'>, {'blue': '2'})
# Game 23: 19 green, 2 blue, 3 red; 1 red, 2 blue, 2 green; 2 blue, 10 green, 11 red
# 10 green
# defaultdict(<class 'int'>, {'blue': '2', 'green': '10'})
# Game 23: 19 green, 2 blue, 3 red; 1 red, 2 blue, 2 green; 2 blue, 10 green, 11 red
# 11 red
# defaultdict(<class 'int'>, {'blue': '2', 'green': '10', 'red': '11'})
# Game 23: 19 green, 2 blue, 3 red; 1 red, 2 blue, 2 green; 2 blue, 10 green, 11 red
# Game 24: 1 red, 3 blue; 2 blue; 1 green, 1 red, 3 blue; 1 red, 1 green
#  1 red, 3 blue
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 24: 1 red, 3 blue; 2 blue; 1 green, 1 red, 3 blue; 1 red, 1 green
# 3 blue
# defaultdict(<class 'int'>, {'red': '1', 'blue': '3'})
# Game 24: 1 red, 3 blue; 2 blue; 1 green, 1 red, 3 blue; 1 red, 1 green
#  2 blue
# 2 blue
# defaultdict(<class 'int'>, {'blue': '2'})
# Game 24: 1 red, 3 blue; 2 blue; 1 green, 1 red, 3 blue; 1 red, 1 green
#  1 green, 1 red, 3 blue
# 1 green
# defaultdict(<class 'int'>, {'green': '1'})
# Game 24: 1 red, 3 blue; 2 blue; 1 green, 1 red, 3 blue; 1 red, 1 green
# 1 red
# defaultdict(<class 'int'>, {'green': '1', 'red': '1'})
# Game 24: 1 red, 3 blue; 2 blue; 1 green, 1 red, 3 blue; 1 red, 1 green
# 3 blue
# defaultdict(<class 'int'>, {'green': '1', 'red': '1', 'blue': '3'})
# Game 24: 1 red, 3 blue; 2 blue; 1 green, 1 red, 3 blue; 1 red, 1 green
#  1 red, 1 green
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 24: 1 red, 3 blue; 2 blue; 1 green, 1 red, 3 blue; 1 red, 1 green
# 1 green
# defaultdict(<class 'int'>, {'red': '1', 'green': '1'})
# Game 24: 1 red, 3 blue; 2 blue; 1 green, 1 red, 3 blue; 1 red, 1 green
# Game 25: 12 green, 2 red, 10 blue; 6 green, 3 red; 3 green, 18 blue, 3 red; 17 green, 3 red, 18 blue
#  12 green, 2 red, 10 blue
# 12 green
# defaultdict(<class 'int'>, {'green': '12'})
# Game 25: 12 green, 2 red, 10 blue; 6 green, 3 red; 3 green, 18 blue, 3 red; 17 green, 3 red, 18 blue
# 2 red
# defaultdict(<class 'int'>, {'green': '12', 'red': '2'})
# Game 25: 12 green, 2 red, 10 blue; 6 green, 3 red; 3 green, 18 blue, 3 red; 17 green, 3 red, 18 blue
# 10 blue
# defaultdict(<class 'int'>, {'green': '12', 'red': '2', 'blue': '10'})
# Game 25: 12 green, 2 red, 10 blue; 6 green, 3 red; 3 green, 18 blue, 3 red; 17 green, 3 red, 18 blue
#  6 green, 3 red
# 6 green
# defaultdict(<class 'int'>, {'green': '6'})
# Game 25: 12 green, 2 red, 10 blue; 6 green, 3 red; 3 green, 18 blue, 3 red; 17 green, 3 red, 18 blue
# 3 red
# defaultdict(<class 'int'>, {'green': '6', 'red': '3'})
# Game 25: 12 green, 2 red, 10 blue; 6 green, 3 red; 3 green, 18 blue, 3 red; 17 green, 3 red, 18 blue
#  3 green, 18 blue, 3 red
# 3 green
# defaultdict(<class 'int'>, {'green': '3'})
# Game 25: 12 green, 2 red, 10 blue; 6 green, 3 red; 3 green, 18 blue, 3 red; 17 green, 3 red, 18 blue
# 18 blue
# defaultdict(<class 'int'>, {'green': '3', 'blue': '18'})
# Game 25: 12 green, 2 red, 10 blue; 6 green, 3 red; 3 green, 18 blue, 3 red; 17 green, 3 red, 18 blue
# 3 red
# defaultdict(<class 'int'>, {'green': '3', 'blue': '18', 'red': '3'})
# Game 25: 12 green, 2 red, 10 blue; 6 green, 3 red; 3 green, 18 blue, 3 red; 17 green, 3 red, 18 blue
#  17 green, 3 red, 18 blue
# ...
#  1 red, 18 blue, 10 green
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 93: 1 blue, 2 green, 1 red; 4 red, 7 green, 12 blue; 6 green, 3 blue, 4 red; 8 blue, 4 red, 12 green; 5 red, 8 green; 1 red, 18 blue, 10 green
# 18 blue
# defaultdict(<class 'int'>, {'red': '1', 'blue': '18'})
# Game 93: 1 blue, 2 green, 1 red; 4 red, 7 green, 12 blue; 6 green, 3 blue, 4 red; 8 blue, 4 red, 12 green; 5 red, 8 green; 1 red, 18 blue, 10 green
# 10 green
# defaultdict(<class 'int'>, {'red': '1', 'blue': '18', 'green': '10'})
# Game 93: 1 blue, 2 green, 1 red; 4 red, 7 green, 12 blue; 6 green, 3 blue, 4 red; 8 blue, 4 red, 12 green; 5 red, 8 green; 1 red, 18 blue, 10 green
# Game 94: 1 blue, 5 red, 6 green; 7 red, 6 green, 1 blue; 8 red, 11 green; 12 green, 7 red, 1 blue; 7 red, 8 green
#  1 blue, 5 red, 6 green
# 1 blue
# defaultdict(<class 'int'>, {'blue': '1'})
# Game 94: 1 blue, 5 red, 6 green; 7 red, 6 green, 1 blue; 8 red, 11 green; 12 green, 7 red, 1 blue; 7 red, 8 green
# 5 red
# defaultdict(<class 'int'>, {'blue': '1', 'red': '5'})
# Game 94: 1 blue, 5 red, 6 green; 7 red, 6 green, 1 blue; 8 red, 11 green; 12 green, 7 red, 1 blue; 7 red, 8 green
# 6 green
# defaultdict(<class 'int'>, {'blue': '1', 'red': '5', 'green': '6'})
# Game 94: 1 blue, 5 red, 6 green; 7 red, 6 green, 1 blue; 8 red, 11 green; 12 green, 7 red, 1 blue; 7 red, 8 green
#  7 red, 6 green, 1 blue
# 7 red
# defaultdict(<class 'int'>, {'red': '7'})
# Game 94: 1 blue, 5 red, 6 green; 7 red, 6 green, 1 blue; 8 red, 11 green; 12 green, 7 red, 1 blue; 7 red, 8 green
# 6 green
# defaultdict(<class 'int'>, {'red': '7', 'green': '6'})
# Game 94: 1 blue, 5 red, 6 green; 7 red, 6 green, 1 blue; 8 red, 11 green; 12 green, 7 red, 1 blue; 7 red, 8 green
# 1 blue
# defaultdict(<class 'int'>, {'red': '7', 'green': '6', 'blue': '1'})
# Game 94: 1 blue, 5 red, 6 green; 7 red, 6 green, 1 blue; 8 red, 11 green; 12 green, 7 red, 1 blue; 7 red, 8 green
#  8 red, 11 green
# 8 red
# defaultdict(<class 'int'>, {'red': '8'})
# Game 94: 1 blue, 5 red, 6 green; 7 red, 6 green, 1 blue; 8 red, 11 green; 12 green, 7 red, 1 blue; 7 red, 8 green
# 11 green
# defaultdict(<class 'int'>, {'red': '8', 'green': '11'})
# Game 94: 1 blue, 5 red, 6 green; 7 red, 6 green, 1 blue; 8 red, 11 green; 12 green, 7 red, 1 blue; 7 red, 8 green
#  12 green, 7 red, 1 blue
# 12 green
# defaultdict(<class 'int'>, {'green': '12'})
# Game 94: 1 blue, 5 red, 6 green; 7 red, 6 green, 1 blue; 8 red, 11 green; 12 green, 7 red, 1 blue; 7 red, 8 green
# 7 red
# defaultdict(<class 'int'>, {'green': '12', 'red': '7'})
# Game 94: 1 blue, 5 red, 6 green; 7 red, 6 green, 1 blue; 8 red, 11 green; 12 green, 7 red, 1 blue; 7 red, 8 green
# 1 blue
# defaultdict(<class 'int'>, {'green': '12', 'red': '7', 'blue': '1'})
# Game 94: 1 blue, 5 red, 6 green; 7 red, 6 green, 1 blue; 8 red, 11 green; 12 green, 7 red, 1 blue; 7 red, 8 green
#  7 red, 8 green
# 7 red
# defaultdict(<class 'int'>, {'red': '7'})
# Game 94: 1 blue, 5 red, 6 green; 7 red, 6 green, 1 blue; 8 red, 11 green; 12 green, 7 red, 1 blue; 7 red, 8 green
# 8 green
# defaultdict(<class 'int'>, {'red': '7', 'green': '8'})
# Game 94: 1 blue, 5 red, 6 green; 7 red, 6 green, 1 blue; 8 red, 11 green; 12 green, 7 red, 1 blue; 7 red, 8 green
# Game 95: 10 red, 7 green; 2 green, 1 blue, 10 red; 6 green, 5 red, 1 blue
#  10 red, 7 green
# 10 red
# defaultdict(<class 'int'>, {'red': '10'})
# Game 95: 10 red, 7 green; 2 green, 1 blue, 10 red; 6 green, 5 red, 1 blue
# 7 green
# defaultdict(<class 'int'>, {'red': '10', 'green': '7'})
# Game 95: 10 red, 7 green; 2 green, 1 blue, 10 red; 6 green, 5 red, 1 blue
#  2 green, 1 blue, 10 red
# 2 green
# defaultdict(<class 'int'>, {'green': '2'})
# Game 95: 10 red, 7 green; 2 green, 1 blue, 10 red; 6 green, 5 red, 1 blue
# 1 blue
# defaultdict(<class 'int'>, {'green': '2', 'blue': '1'})
# Game 95: 10 red, 7 green; 2 green, 1 blue, 10 red; 6 green, 5 red, 1 blue
# 10 red
# defaultdict(<class 'int'>, {'green': '2', 'blue': '1', 'red': '10'})
# Game 95: 10 red, 7 green; 2 green, 1 blue, 10 red; 6 green, 5 red, 1 blue
#  6 green, 5 red, 1 blue
# 6 green
# defaultdict(<class 'int'>, {'green': '6'})
# Game 95: 10 red, 7 green; 2 green, 1 blue, 10 red; 6 green, 5 red, 1 blue
# 5 red
# defaultdict(<class 'int'>, {'green': '6', 'red': '5'})
# Game 95: 10 red, 7 green; 2 green, 1 blue, 10 red; 6 green, 5 red, 1 blue
# 1 blue
# defaultdict(<class 'int'>, {'green': '6', 'red': '5', 'blue': '1'})
# Game 95: 10 red, 7 green; 2 green, 1 blue, 10 red; 6 green, 5 red, 1 blue
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
#  3 blue, 12 red, 3 green
# 3 blue
# defaultdict(<class 'int'>, {'blue': '3'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
# 12 red
# defaultdict(<class 'int'>, {'blue': '3', 'red': '12'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
# 3 green
# defaultdict(<class 'int'>, {'blue': '3', 'red': '12', 'green': '3'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
#  13 red, 9 blue
# 13 red
# defaultdict(<class 'int'>, {'red': '13'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
# 9 blue
# defaultdict(<class 'int'>, {'red': '13', 'blue': '9'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
#  2 green, 5 red, 13 blue
# 2 green
# defaultdict(<class 'int'>, {'green': '2'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
# 5 red
# defaultdict(<class 'int'>, {'green': '2', 'red': '5'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
# 13 blue
# defaultdict(<class 'int'>, {'green': '2', 'red': '5', 'blue': '13'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
#  2 red, 18 blue, 4 green
# 2 red
# defaultdict(<class 'int'>, {'red': '2'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
# 18 blue
# defaultdict(<class 'int'>, {'red': '2', 'blue': '18'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
# 4 green
# defaultdict(<class 'int'>, {'red': '2', 'blue': '18', 'green': '4'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
#  6 red, 6 blue, 7 green
# 6 red
# defaultdict(<class 'int'>, {'red': '6'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
# 6 blue
# defaultdict(<class 'int'>, {'red': '6', 'blue': '6'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
# 7 green
# defaultdict(<class 'int'>, {'red': '6', 'blue': '6', 'green': '7'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
#  3 green, 15 red, 18 blue
# 3 green
# defaultdict(<class 'int'>, {'green': '3'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
# 15 red
# defaultdict(<class 'int'>, {'green': '3', 'red': '15'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
# 18 blue
# defaultdict(<class 'int'>, {'green': '3', 'red': '15', 'blue': '18'})
# Game 96: 3 blue, 12 red, 3 green; 13 red, 9 blue; 2 green, 5 red, 13 blue; 2 red, 18 blue, 4 green; 6 red, 6 blue, 7 green; 3 green, 15 red, 18 blue
# Game 97: 4 red, 3 green; 2 blue, 4 red, 5 green; 3 red, 3 green
#  4 red, 3 green
# 4 red
# defaultdict(<class 'int'>, {'red': '4'})
# Game 97: 4 red, 3 green; 2 blue, 4 red, 5 green; 3 red, 3 green
# 3 green
# defaultdict(<class 'int'>, {'red': '4', 'green': '3'})
# Game 97: 4 red, 3 green; 2 blue, 4 red, 5 green; 3 red, 3 green
#  2 blue, 4 red, 5 green
# 2 blue
# defaultdict(<class 'int'>, {'blue': '2'})
# Game 97: 4 red, 3 green; 2 blue, 4 red, 5 green; 3 red, 3 green
# 4 red
# defaultdict(<class 'int'>, {'blue': '2', 'red': '4'})
# Game 97: 4 red, 3 green; 2 blue, 4 red, 5 green; 3 red, 3 green
# 5 green
# defaultdict(<class 'int'>, {'blue': '2', 'red': '4', 'green': '5'})
# Game 97: 4 red, 3 green; 2 blue, 4 red, 5 green; 3 red, 3 green
#  3 red, 3 green
# 3 red
# defaultdict(<class 'int'>, {'red': '3'})
# Game 97: 4 red, 3 green; 2 blue, 4 red, 5 green; 3 red, 3 green
# 3 green
# defaultdict(<class 'int'>, {'red': '3', 'green': '3'})
# Game 97: 4 red, 3 green; 2 blue, 4 red, 5 green; 3 red, 3 green
# Game 98: 2 red, 19 blue; 2 blue; 11 blue, 2 red; 3 green, 5 blue, 1 red; 2 red, 1 blue; 17 blue
#  2 red, 19 blue
# 2 red
# defaultdict(<class 'int'>, {'red': '2'})
# Game 98: 2 red, 19 blue; 2 blue; 11 blue, 2 red; 3 green, 5 blue, 1 red; 2 red, 1 blue; 17 blue
# 19 blue
# defaultdict(<class 'int'>, {'red': '2', 'blue': '19'})
# Game 98: 2 red, 19 blue; 2 blue; 11 blue, 2 red; 3 green, 5 blue, 1 red; 2 red, 1 blue; 17 blue
#  2 blue
# 2 blue
# defaultdict(<class 'int'>, {'blue': '2'})
# Game 98: 2 red, 19 blue; 2 blue; 11 blue, 2 red; 3 green, 5 blue, 1 red; 2 red, 1 blue; 17 blue
#  11 blue, 2 red
# 11 blue
# defaultdict(<class 'int'>, {'blue': '11'})
# Game 98: 2 red, 19 blue; 2 blue; 11 blue, 2 red; 3 green, 5 blue, 1 red; 2 red, 1 blue; 17 blue
# 2 red
# defaultdict(<class 'int'>, {'blue': '11', 'red': '2'})
# Game 98: 2 red, 19 blue; 2 blue; 11 blue, 2 red; 3 green, 5 blue, 1 red; 2 red, 1 blue; 17 blue
#  3 green, 5 blue, 1 red
# 3 green
# defaultdict(<class 'int'>, {'green': '3'})
# Game 98: 2 red, 19 blue; 2 blue; 11 blue, 2 red; 3 green, 5 blue, 1 red; 2 red, 1 blue; 17 blue
# 5 blue
# defaultdict(<class 'int'>, {'green': '3', 'blue': '5'})
# Game 98: 2 red, 19 blue; 2 blue; 11 blue, 2 red; 3 green, 5 blue, 1 red; 2 red, 1 blue; 17 blue
# 1 red
# defaultdict(<class 'int'>, {'green': '3', 'blue': '5', 'red': '1'})
# Game 98: 2 red, 19 blue; 2 blue; 11 blue, 2 red; 3 green, 5 blue, 1 red; 2 red, 1 blue; 17 blue
#  2 red, 1 blue
# 2 red
# defaultdict(<class 'int'>, {'red': '2'})
# Game 98: 2 red, 19 blue; 2 blue; 11 blue, 2 red; 3 green, 5 blue, 1 red; 2 red, 1 blue; 17 blue
# 1 blue
# defaultdict(<class 'int'>, {'red': '2', 'blue': '1'})
# Game 98: 2 red, 19 blue; 2 blue; 11 blue, 2 red; 3 green, 5 blue, 1 red; 2 red, 1 blue; 17 blue
#  17 blue
# 17 blue
# defaultdict(<class 'int'>, {'blue': '17'})
# Game 98: 2 red, 19 blue; 2 blue; 11 blue, 2 red; 3 green, 5 blue, 1 red; 2 red, 1 blue; 17 blue
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
#  2 red, 16 blue, 1 green
# 2 red
# defaultdict(<class 'int'>, {'red': '2'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
# 16 blue
# defaultdict(<class 'int'>, {'red': '2', 'blue': '16'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
# 1 green
# defaultdict(<class 'int'>, {'red': '2', 'blue': '16', 'green': '1'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
#  2 green, 12 blue, 6 red
# 2 green
# defaultdict(<class 'int'>, {'green': '2'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
# 12 blue
# defaultdict(<class 'int'>, {'green': '2', 'blue': '12'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
# 6 red
# defaultdict(<class 'int'>, {'green': '2', 'blue': '12', 'red': '6'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
#  1 red, 3 green, 3 blue
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
# 3 green
# defaultdict(<class 'int'>, {'red': '1', 'green': '3'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
# 3 blue
# defaultdict(<class 'int'>, {'red': '1', 'green': '3', 'blue': '3'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
#  8 red, 1 green
# 8 red
# defaultdict(<class 'int'>, {'red': '8'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
# 1 green
# defaultdict(<class 'int'>, {'red': '8', 'green': '1'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
#  2 red, 9 blue
# 2 red
# defaultdict(<class 'int'>, {'red': '2'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
# 9 blue
# defaultdict(<class 'int'>, {'red': '2', 'blue': '9'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
#  1 green, 7 red, 9 blue
# 1 green
# defaultdict(<class 'int'>, {'green': '1'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
# 7 red
# defaultdict(<class 'int'>, {'green': '1', 'red': '7'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
# 9 blue
# defaultdict(<class 'int'>, {'green': '1', 'red': '7', 'blue': '9'})
# Game 99: 2 red, 16 blue, 1 green; 2 green, 12 blue, 6 red; 1 red, 3 green, 3 blue; 8 red, 1 green; 2 red, 9 blue; 1 green, 7 red, 9 blue
# Game 100: 8 green, 3 red; 7 green, 4 red; 1 red, 7 green, 2 blue; 1 green, 2 red
#  8 green, 3 red
# 8 green
# defaultdict(<class 'int'>, {'green': '8'})
# Game 100: 8 green, 3 red; 7 green, 4 red; 1 red, 7 green, 2 blue; 1 green, 2 red
# 3 red
# defaultdict(<class 'int'>, {'green': '8', 'red': '3'})
# Game 100: 8 green, 3 red; 7 green, 4 red; 1 red, 7 green, 2 blue; 1 green, 2 red
#  7 green, 4 red
# 7 green
# defaultdict(<class 'int'>, {'green': '7'})
# Game 100: 8 green, 3 red; 7 green, 4 red; 1 red, 7 green, 2 blue; 1 green, 2 red
# 4 red
# defaultdict(<class 'int'>, {'green': '7', 'red': '4'})
# Game 100: 8 green, 3 red; 7 green, 4 red; 1 red, 7 green, 2 blue; 1 green, 2 red
#  1 red, 7 green, 2 blue
# 1 red
# defaultdict(<class 'int'>, {'red': '1'})
# Game 100: 8 green, 3 red; 7 green, 4 red; 1 red, 7 green, 2 blue; 1 green, 2 red
# 7 green
# defaultdict(<class 'int'>, {'red': '1', 'green': '7'})
# Game 100: 8 green, 3 red; 7 green, 4 red; 1 red, 7 green, 2 blue; 1 green, 2 red
# 2 blue
# defaultdict(<class 'int'>, {'red': '1', 'green': '7', 'blue': '2'})
# Game 100: 8 green, 3 red; 7 green, 4 red; 1 red, 7 green, 2 blue; 1 green, 2 red
#  1 green, 2 red
# 1 green
# defaultdict(<class 'int'>, {'green': '1'})
# Game 100: 8 green, 3 red; 7 green, 4 red; 1 red, 7 green, 2 blue; 1 green, 2 red
# 2 red
# defaultdict(<class 'int'>, {'green': '1', 'red': '2'})
# Game 100: 8 green, 3 red; 7 green, 4 red; 1 red, 7 green, 2 blue; 1 green, 2 red

# %% [markdown]
# The Elf says they've stopped producing snow because they aren't getting any water! He isn't sure why the water stopped; however, he can show you how to get to the water source to check it out for yourself. It's just up ahead!
#
# As you continue your walk, the Elf poses a second question: in each game you played, what is the fewest number of cubes of each color that could have been in the bag to make the game possible?
#
# Again consider the example games from earlier:
#
# ```
# Game 1: 3 blue, 4 red; 1 red, 2 green, 6 blue; 2 green
# Game 2: 1 blue, 2 green; 3 green, 4 blue, 1 red; 1 green, 1 blue
# Game 3: 8 green, 6 blue, 20 red; 5 blue, 4 red, 13 green; 5 green, 1 red
# Game 4: 1 green, 3 red, 6 blue; 3 green, 6 red; 3 green, 15 blue, 14 red
# Game 5: 6 red, 1 blue, 3 green; 2 blue, 1 red, 2 green
# ```
#
# In game 1, the game could have been played with as few as 4 red, 2 green, and 6 blue cubes. If any color had even one fewer cube, the game would have been impossible.
# Game 2 could have been played with a minimum of 1 red, 3 green, and 4 blue cubes.
# Game 3 must have been played with at least 20 red, 13 green, and 6 blue cubes.
# Game 4 required at least 14 red, 3 green, and 15 blue cubes.
# Game 5 needed no fewer than 6 red, 3 green, and 2 blue cubes in the bag.
# The power of a set of cubes is equal to the numbers of red, green, and blue cubes multiplied together. The power of the minimum set of cubes in game 1 is 48. In games 2-5 it was 12, 1560, 630, and 36, respectively. Adding up these five powers produces the sum 2286.
#
# For each game, find the minimum set of cubes that must have been present. What is the sum of the power of these sets?

# %%
from collections import defaultdict

tot = 0
for id, game in enumerate(games):
    game = game.rstrip(r"\n")
    game = game.rstrip("\n")
    minigames = game.split(":")[1].split(";")
    draws_dict = defaultdict(int)
    for minigame in minigames:
        draws = minigame.split(",")
        for draw in draws:
            val, cat = draw.split(" ")[1], draw.split(" ")[2]
            draws_dict[cat] = max(int(val), draws_dict[cat])
    temp = 1
    for val in draws_dict.values():
        temp *= val
    tot += temp

# %%
tot
# Out:
# 54911
